# %%
import numpy as np

# %%
rng = np.random.default_rng()

# %%
rng.integers(1,7)
# Out:
# np.int64(5)

# %%
rng.integers(low=1,high=101)
# Out:
# np.int64(8)

# %% [markdown]
# count is given in size

# %%
rng.integers(low=1,high=101,size=10)
# Out:
# array([57,  9, 32,  6, 49, 85, 50, 10, 39, 91])

# %% [markdown]
# dimension

# %%
rng.integers(low=1,high=101,size=(3,2))
# Out:
# array([[52, 92],
#        [81, 55],
#        [32, 12]])

# %% [markdown]
# seed used to reproduce same results

# %%
rng = np.random.default_rng(seed=1)

# %%
rng.integers(low=1,high=101,size=(3,2))
# Out:
# array([[13, 46],
#        [98, 14],
#        [39, 41]])

# %% [markdown]
# floating point num

# %%
rn=np.random.uniform()

# %%
rn
# Out:
# 0.8027396661682495

# %% [markdown]
# range

# %%
rn=np.random.uniform(-1,1)

# %%
rn
# Out:
# -0.388664620823546

# %%
rn=np.random.seed()

# %%
rn=np.random.uniform(-1,1,size=(3,2))
rn
# Out:
# array([[ 0.99676293,  0.07188405],
#        [-0.93781148,  0.60339002],
#        [-0.52808275,  0.04760687]])

# %%
a=np.array([1,2,3,4,5])

# %%
a
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# shuffle

# %%
rng=np.random.default_rng()

# %%
rng.shuffle(a)
# Out:
# None

# %%
a
# Out:
# array([4, 3, 5, 2, 1])

# %%
a
# Out:
# array([4, 3, 5, 2, 1])

# %%
fruits=(['apple','orange','kiwi','butter'])

# %%
rng.shuffle(fruits)

# %%
fruits
# Out:
# ['orange', 'kiwi', 'butter', 'apple']

# %%
fruit=rng.choice(fruits)

# %%
fruit
# Out:
# np.str_('apple')

# %%
fruit=rng.choice(fruits,size=(3))

# %%
fruit
# Out:
# array(['orange', 'orange', 'kiwi'], dtype='<U6')

# %%
fruit=rng.choice(fruits,size=(3,2))

# %%
fruitss=np.array(["🍒","🍓","🍌","🥝"])

# %%
fruitss
# Out:
# array(['🍒', '🍓', '🍌', '🥝'], dtype='<U1')

# %%
rng.choice(fruitss)
# Out:
# np.str_('🍌')
