# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('carprices-2.csv')
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
plt.scatter(df['Mileage'], df['Sell Price($)'])

# %%
plt.scatter(df['Age(yrs)'], df['Sell Price($)'],color='red', marker='x')

# %%
X = df[['Mileage','Age(yrs)']]
y = df['Sell Price($)']

# %%
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# training & testing

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)#random_state=10
#means test is 20%. remaining 80 for training

# %% [markdown]
# when u execute above cell and then the below one, they choose values randomly . now with random_state it won't change

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 1     35000         3
# 0     69000         6
# 18    87600         8
# 4     46000         4
# 14    82450         7
# 9     67000         6
# 13    58780         4
# 15    25400         3
# 16    28000         2
# 3     22500         2
# 17    69000         5
# 12    59000         5
# 19    52000         5
# 2     57000         5
# 11    79000         7
# 7     72000         6

# %%
len(X_train) #gives 80% of dataset
# Out:
# 16

# %%
len(X_test)
# Out:
# 4

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([27249.04328129, 13234.96133833, 16420.37704258, 25168.72036052])

# %%
X_test #not so accurate
# Out:
#     Mileage  Age(yrs)
# 6     52000         5
# 8     91000         8
# 10    83000         7
# 5     59000         5

# %%
model.score(X_test,y_test)
# Out:
# 0.8635028895808304
