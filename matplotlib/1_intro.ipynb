# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,49,47,46]

# %%
plt.plot(x,y)

# %% [markdown]
# LABELLING

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y,color='red',linewidth=2,linestyle='dashdot') #arguments
