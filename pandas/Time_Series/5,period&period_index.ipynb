# %%
import pandas as pd

# %%
y = pd.Period('2016')
y
# Out:
# Period('2016', 'Y-DEC')

# %%
dir(y) #shows properties of period
# Out:
# ['__add__',
#  '__array_priority__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_cython__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__setstate__',
#  '__setstate_cython__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_offset',
#  '_add_timedeltalike_scalar',
#  '_dtype',
#  '_freq',
#  '_from_ordinal',
#  '_maybe_convert_freq',
#  '_ordinal',
#  '_require_matching_freq',
#  'asfreq',
#  'day',
#  'day_of_week',
#  'day_of_year',
#  'dayofweek',
#  'dayofyear',
#  'days_in_month',
#  'daysinmonth',
#  'end_time',
#  'freq',
#  'freqstr',
#  'hour',
#  'is_leap_year',
#  'minute',
#  'month',
#  'now',
# ...

# %%
y.start_time , y.end_time
# Out:
# (Timestamp('2016-01-01 00:00:00'), Timestamp('2016-12-31 23:59:59.999999'))

# %% [markdown]
# MONTHLY

# %%
m =pd.Period('2011-12',freq='M')
m
# Out:
# Period('2011-12', 'M')

# %%
m.end_time
# Out:
# Timestamp('2011-12-31 23:59:59.999999')

# %% [markdown]
# takwes you to next year

# %%
m +1
# Out:
# Period('2012-01', 'M')

# %% [markdown]
# DAILY

# %%
d = pd.Period('2016-02-28')
d
# Out:
# Period('2016-02-28', 'D')

# %% [markdown]
# leap year is considered in Period

# %%
d+1
# Out:
# Period('2016-02-29', 'D')

# %%
d.start_time
# Out:
# Timestamp('2016-02-28 00:00:00')

# %% [markdown]
# HOURLY

# %%
h = pd.Period('2016-02-28 23:00:00','h')
h
# Out:
# Period('2016-02-28 23:00', 'h')

# %%
h.start_time
# Out:
# Timestamp('2016-02-28 23:00:00')

# %%
h+pd.offsets.Hour(5)
# Out:
# Period('2016-02-29 04:00', 'h')

# %%
h.end_time
# Out:
# Timestamp('2016-02-28 23:59:59.999999')

# %%
h-6
# Out:
# Period('2016-02-28 17:00', 'h')

# %% [markdown]
# Quarterly time period

# %%
q = pd.Period("2017Q1")
q
# Out:
# Period('2017Q1', 'Q-DEC')

# %%
q+1
# Out:
# Period('2017Q2', 'Q-DEC')

# %%
q = pd.Period("2017Q1",freq = "Q-JAN") # end in jan
q
# Out:
# Period('2017Q1', 'Q-JAN')

# %%
q.start_time
# Out:
# Timestamp('2016-02-01 00:00:00')

# %% [markdown]
# Another way of qtl

# %%
q = pd.Period("2016-02-28 23:00:00","Q")
q
# Out:
# Period('2016Q1', 'Q-DEC')

# %%
q.asfreq("M",how="end")
# Out:
# Period('2016-03', 'M')

# %%
q2 = pd.Period("2018Q2")

# %%
q2-q
# Out:
# <9 * QuarterEnds: startingMonth=12>

# %% [markdown]
# PERIODINDEX

# %%
idx = pd.period_range('2011','2017',freq='Q-JAN')
idx
# Out:
# PeriodIndex(['2011Q4', '2012Q1', '2012Q2', '2012Q3', '2012Q4', '2013Q1',
#              '2013Q2', '2013Q3', '2013Q4', '2014Q1', '2014Q2', '2014Q3',
#              '2014Q4', '2015Q1', '2015Q2', '2015Q3', '2015Q4', '2016Q1',
#              '2016Q2', '2016Q3', '2016Q4', '2017Q1', '2017Q2', '2017Q3',
#              '2017Q4'],
#             dtype='period[Q-JAN]')

# %%
idx[0].start_time
# Out:
# Timestamp('2010-11-01 00:00:00')

# %%
idx[0].end_time
# Out:
# Timestamp('2011-01-31 23:59:59.999999')

# %%
import numpy as np
ps = pd.Series(np.random.randn(len(idx)),idx)
ps
# Out:
# 2011Q4   -0.111027
# 2012Q1    1.231689
# 2012Q2   -0.764966
# 2012Q3    1.920327
# 2012Q4    1.429635
# 2013Q1   -0.666150
# 2013Q2    0.230249
# 2013Q3   -1.860422
# 2013Q4   -0.530633
# 2014Q1   -0.981864
# 2014Q2   -0.892349
# 2014Q3   -3.196675
# 2014Q4   -0.309708
# 2015Q1    0.196450
# 2015Q2    0.769727
# 2015Q3    0.373447
# 2015Q4   -0.164276
# 2016Q1    0.953931
# 2016Q2    0.439067
# 2016Q3   -0.513027
# 2016Q4    1.104719
# 2017Q1    1.389443
# 2017Q2    1.761354
# 2017Q3    1.333310
# 2017Q4    0.852550
# Freq: Q-JAN, dtype: float64

# %%
ps.index
# Out:
# PeriodIndex(['2011Q4', '2012Q1', '2012Q2', '2012Q3', '2012Q4', '2013Q1',
#              '2013Q2', '2013Q3', '2013Q4', '2014Q1', '2014Q2', '2014Q3',
#              '2014Q4', '2015Q1', '2015Q2', '2015Q3', '2015Q4', '2016Q1',
#              '2016Q2', '2016Q3', '2016Q4', '2017Q1', '2017Q2', '2017Q3',
#              '2017Q4'],
#             dtype='period[Q-JAN]')

# %% [markdown]
# Retrieving values

# %%
ps['2011':'2013']
# Out:
# 2011Q4   -0.111027
# 2012Q1    1.231689
# 2012Q2   -0.764966
# 2012Q3    1.920327
# 2012Q4    1.429635
# 2013Q1   -0.666150
# 2013Q2    0.230249
# 2013Q3   -1.860422
# 2013Q4   -0.530633
# 2014Q1   -0.981864
# 2014Q2   -0.892349
# 2014Q3   -3.196675
# 2014Q4   -0.309708
# Freq: Q-JAN, dtype: float64

# %%
df = pd.read_csv("wmt.csv")
df
# Out:
#   Line Item  2017Q1  2017Q2  2017Q3  2017Q4  2018Q1
# 0   Revenue  115904  120854  118179  130936  117542
# 1  Expenses   86544   89485   87484   97743   87688
# 2    Profit   29360   31369   30695   33193   29854

# %%
df.set_index('Line Item',inplace=True)

# %%
df
# Out:
#            2017Q1  2017Q2  2017Q3  2017Q4  2018Q1
# Line Item
# Revenue    115904  120854  118179  130936  117542
# Expenses    86544   89485   87484   97743   87688
# Profit      29360   31369   30695   33193   29854

# %%
df=df.T  #transpose table
df
# Out:
# Line Item  Revenue  Expenses  Profit
# 2017Q1      115904     86544   29360
# 2017Q2      120854     89485   31369
# 2017Q3      118179     87484   30695
# 2017Q4      130936     97743   33193
# 2018Q1      117542     87688   29854

# %%
df.index
# Out:
# PeriodIndex(['2017Q1', '2017Q2', '2017Q3', '2017Q4', '2018Q1'], dtype='period[Q-JAN]')

# %%
df['start_date']= df.index.map(lambda x:x.start_time)
df['end_date']=df.index.map(lambda x:x.end_time)

# %%
df
# Out:
# Line Item  Revenue  Expenses  Profit start_date                   end_date
# 2017Q1      115904     86544   29360 2016-02-01 2016-04-30 23:59:59.999999
# 2017Q2      120854     89485   31369 2016-05-01 2016-07-31 23:59:59.999999
# 2017Q3      118179     87484   30695 2016-08-01 2016-10-31 23:59:59.999999
# 2017Q4      130936     97743   33193 2016-11-01 2017-01-31 23:59:59.999999
# 2018Q1      117542     87688   29854 2017-02-01 2017-04-30 23:59:59.999999
