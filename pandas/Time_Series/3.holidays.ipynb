# %%
import pandas as pd

# %%
df = pd.read_csv("aapl_no_dates.csv")
df.head()
# Out:
#      Open    High     Low   Close    Volume
# 0  144.88  145.30  143.10  143.50  14277848
# 1  143.69  144.79  142.72  144.09  21569557
# 2  143.02  143.50  142.41  142.73  24128782
# 3  142.90  144.75  142.90  144.18  19201712
# 4  144.11  145.95  143.37  145.06  21090636

# %%
pd.date_range(start="7/1/2017" , end="7/21/2017", freq="B")
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-04', '2017-07-05', '2017-07-06',
#                '2017-07-07', '2017-07-10', '2017-07-11', '2017-07-12',
#                '2017-07-13', '2017-07-14', '2017-07-17', '2017-07-18',
#                '2017-07-19', '2017-07-20', '2017-07-21'],
#               dtype='datetime64[us]', freq='B')

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

# %%
usb = CustomBusinessDay(calendar=USFederalHolidayCalendar())

# %%
rng = pd.date_range(start="7/1/2017" , end="7/21/2017", freq=usb)

# %%
df.set_index(rng,inplace=True)

# %% [markdown]
# CREATING CUSTOM HOLIDAY CALENDAR

# %%
from pandas.tseries.holiday import AbstractHolidayCalendar, nearest_workday, Holiday
class myCalendar(AbstractHolidayCalendar):
    rules = [
        Holiday('My Birth Day', month=2, day=27,observance=nearest_workday),
    ]

my_bday = CustomBusinessDay(calendar=myCalendar())
pd.date_range('2/1/2017','2/28/2017',freq=my_bday)
# Out:
# DatetimeIndex(['2017-02-01', '2017-02-02', '2017-02-03', '2017-02-06',
#                '2017-02-07', '2017-02-08', '2017-02-09', '2017-02-10',
#                '2017-02-13', '2017-02-14', '2017-02-15', '2017-02-16',
#                '2017-02-17', '2017-02-20', '2017-02-21', '2017-02-22',
#                '2017-02-23', '2017-02-24', '2017-02-28'],
#               dtype='datetime64[us]', freq='C')

# %%
egypt_weekdays = "Sun Mon Tue Wed Thu"
b = CustomBusinessDay(weekmask=egypt_weekdays, holidays = ["2017-07-12"]) #adding a custom holiday
pd.date_range(start="7/1/2017",periods=40,freq=b)
# Out:
# DatetimeIndex(['2017-07-02', '2017-07-03', '2017-07-04', '2017-07-05',
#                '2017-07-06', '2017-07-09', '2017-07-10', '2017-07-11',
#                '2017-07-13', '2017-07-16', '2017-07-17', '2017-07-18',
#                '2017-07-19', '2017-07-20', '2017-07-23', '2017-07-24',
#                '2017-07-25', '2017-07-26', '2017-07-27', '2017-07-30',
#                '2017-07-31', '2017-08-01', '2017-08-02', '2017-08-03',
#                '2017-08-06', '2017-08-07', '2017-08-08', '2017-08-09',
#                '2017-08-10', '2017-08-13', '2017-08-14', '2017-08-15',
#                '2017-08-16', '2017-08-17', '2017-08-20', '2017-08-21',
#                '2017-08-22', '2017-08-23', '2017-08-24', '2017-08-27'],
#               dtype='datetime64[us]', freq='C')
