# %%
import tensorflow as tf
from tensorflow import keras
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import tensorflow as tf
#       2 from tensorflow import keras
#
# File ~/git/Learning-DS/.venv/lib/python3.12/site-packages/tensorflow/__init__.py:469
#     467     importlib.import_module("tf_keras.src.optimizers")
#     468   else:
# --> 469     importlib.import_module("keras.src.optimizers")
#     470 except (ImportError, AttributeError):
#     471   pass
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/git/Learning-DS/.venv/lib/python3.12/site-packages/keras/__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
# ...
